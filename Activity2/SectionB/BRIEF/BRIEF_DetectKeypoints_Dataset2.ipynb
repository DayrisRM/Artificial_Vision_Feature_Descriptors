# %%
import numpy as np
import os
import cv2

# %%
def printImage(image):
  from matplotlib import pyplot as plt
  #Show the image with matplotlib
  plt.imshow(image)
  plt.show()

# %%
directory_folder = '/content/dataset2_reyCopia'
directory_tocopy_folder = '/content/dataset2_keypoints'
dir_images = os.listdir(directory_folder)

# %%
fast = cv2.FastFeatureDetector_create() 
brief = cv2.xfeatures2d.BriefDescriptorExtractor_create()

# %%
def detectKeypoints(image_name):  
  dir_image = f'{directory_folder}/{image_name}' 
  dir_tosave_image = f'{directory_tocopy_folder}/{image_name}'  
  image=cv2.imread(dir_image)
  # Detect keypoints with non max suppression
  keypoints = fast.detect(image, None)
  keypoints, brief_descriptor = brief.compute(image, keypoints)
  
  print (image_name)
  print ('Extracted '+str(len(keypoints))+' keypoints.')

  img=cv2.drawKeypoints(image,keypoints,image)
  cv2.imwrite(dir_tosave_image,image)
  printImage(image)
  print ('----------------')
  print ('')

# %%
for image_name in dir_images:
  detectKeypoints(image_name)
# Out:
# rey-210Ev2.png
# Extracted 712 keypoints.
# ----------------
#
# rey-202Ev4.png
# Extracted 805 keypoints.
# ----------------
#
# rey-213Ev1.png
# Extracted 731 keypoints.
# ----------------
#
# rey-206Ev2.png
# Extracted 581 keypoints.
# ----------------
#
# rey-204Ev1.png
# Extracted 1136 keypoints.
# ----------------
#
# rey-208Ev2.png
# Extracted 711 keypoints.
# ----------------
#
# rey-205Ev4.png
# Extracted 708 keypoints.
# ----------------
#
# rey-212Ev2.png
# Extracted 863 keypoints.
# ----------------
#
# rey-206Ev3.png
# Extracted 683 keypoints.
# ----------------
#
# rey-203Ev2.png
# Extracted 855 keypoints.
# ----------------
#
# rey-202Ev2.png
# Extracted 1022 keypoints.
# ----------------
#
# rey-205Ev1.png
# Extracted 916 keypoints.
# ----------------
#
# rey-202Ev5.png
# Extracted 829 keypoints.
# ----------------
#
# rey-205Ev3.png
# Extracted 864 keypoints.
# ----------------
#
# rey-206Ev5.png
# Extracted 892 keypoints.
# ----------------
#
# rey-202Ev1.png
# Extracted 934 keypoints.
# ----------------
#
# rey-205Ev41.png
# Extracted 817 keypoints.
# ----------------
#
# rey-202Ev3.png
# Extracted 898 keypoints.
# ----------------
#
# rey_modelo.png
# Extracted 513 keypoints.
# ----------------
#
# rey-209Ev3.png
# Extracted 1179 keypoints.
# ----------------
#
# rey-209Ev2.png
# Extracted 698 keypoints.
# ----------------
