# %%
import numpy as np
import os
import cv2

# %%
directory_folder = '/content/dataset2_reyCopia'
directory_tocopy_folder = '/content/dataset2_keypoints'
dir_images = os.listdir(directory_folder)

# %%
def printImage(image):
  from matplotlib import pyplot as plt
  #Show the image with matplotlib
  plt.imshow(image)
  plt.show()

# %%
# Create detector
fast = cv2.FastFeatureDetector_create()

# %%
def detectKeypoints(image_name):  
  dir_image = f'{directory_folder}/{image_name}' 
  dir_tosave_image = f'{directory_tocopy_folder}/{image_name}'  
  image=cv2.imread(dir_image)
  # Detect keypoints with non max suppression
  keypoints_with_nonmax = fast.detect(image, None)
  
  print (image_name)
  print ('Extracted '+str(len(keypoints_with_nonmax))+' keypoints.')

  img=cv2.drawKeypoints(image,keypoints_with_nonmax,image)
  cv2.imwrite(dir_tosave_image,image)
  printImage(image)
  print ('----------------')
  print ('')

# %%
for image_name in dir_images:
  detectKeypoints(image_name)
# Out:
# rey-210Ev2.png
# Extracted 722 keypoints.
# ----------------
#
# rey-202Ev4.png
# Extracted 870 keypoints.
# ----------------
#
# rey-213Ev1.png
# Extracted 742 keypoints.
# ----------------
#
# rey-206Ev2.png
# Extracted 583 keypoints.
# ----------------
#
# rey-204Ev1.png
# Extracted 1227 keypoints.
# ----------------
#
# rey-208Ev2.png
# Extracted 778 keypoints.
# ----------------
#
# rey-205Ev4.png
# Extracted 799 keypoints.
# ----------------
#
# rey-212Ev2.png
# Extracted 885 keypoints.
# ----------------
#
# rey-206Ev3.png
# Extracted 727 keypoints.
# ----------------
#
# rey-203Ev2.png
# Extracted 876 keypoints.
# ----------------
#
# rey-202Ev2.png
# Extracted 1042 keypoints.
# ----------------
#
# rey-205Ev1.png
# Extracted 941 keypoints.
# ----------------
#
# rey-202Ev5.png
# Extracted 831 keypoints.
# ----------------
#
# rey-205Ev3.png
# Extracted 870 keypoints.
# ----------------
#
# rey-206Ev5.png
# Extracted 924 keypoints.
# ----------------
#
# rey-202Ev1.png
# Extracted 937 keypoints.
# ----------------
#
# rey-205Ev41.png
# Extracted 817 keypoints.
# ----------------
#
# rey-202Ev3.png
# Extracted 923 keypoints.
# ----------------
#
# rey_modelo.png
# Extracted 569 keypoints.
# ----------------
#
# rey-209Ev3.png
# Extracted 1209 keypoints.
# ----------------
#
# rey-209Ev2.png
# Extracted 731 keypoints.
# ----------------
