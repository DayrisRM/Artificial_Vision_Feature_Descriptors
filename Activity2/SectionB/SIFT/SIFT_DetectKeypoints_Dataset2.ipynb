# %%
import numpy as np
import os

# %%
# !pip install opencv-contrib-python==4.4.0.44
import cv2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opencv-contrib-python==4.4.0.44
#   Downloading opencv_contrib_python-4.4.0.44-cp37-cp37m-manylinux2014_x86_64.whl (55.7 MB)
#      |████████████████████████████████| 55.7 MB 1.1 MB/s
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-contrib-python==4.4.0.44) (1.21.6)
# Installing collected packages: opencv-contrib-python
#   Attempting uninstall: opencv-contrib-python
#     Found existing installation: opencv-contrib-python 4.1.2.30
#     Uninstalling opencv-contrib-python-4.1.2.30:
#       Successfully uninstalled opencv-contrib-python-4.1.2.30
# Successfully installed opencv-contrib-python-4.4.0.44

# %%
def printImage(image):
  from matplotlib import pyplot as plt
  #Show the image with matplotlib
  plt.imshow(image)
  plt.show()

# %%
directory_folder = '/content/dataset2_reyCopia'
directory_tocopy_folder = '/content/dataset2_keypoints'
dir_images = os.listdir(directory_folder)

# %%
# Create detector to compute SIFT
sift = cv2.SIFT_create()

# %%
def detectKeypoints(image_name):  
  dir_image = f'{directory_folder}/{image_name}' 
  dir_tosave_image = f'{directory_tocopy_folder}/{image_name}'  
  image=cv2.imread(dir_image)  
  # Detect keypoints with SIFT and sort them according to their response
  kpts=sift.detect(image)
  kpts,des=sift.compute(image,kpts)

  print (image_name)
  print ('Extracted '+str(len(kpts))+' keypoints.') 
  
  img=cv2.drawKeypoints(image,kpts,image,flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
  cv2.imwrite(dir_tosave_image,image)
  printImage(image)
  print ('----------------')
  print ('')

# %%
for image_name in dir_images:
  detectKeypoints(image_name)
# Out:
# rey-202Ev4.png
# Extracted 55 keypoints.
# ----------------
#
# rey-206Ev3.png
# Extracted 123 keypoints.
# ----------------
#
# rey-210Ev2.png
# Extracted 58 keypoints.
# ----------------
#
# rey_modelo.png
# Extracted 453 keypoints.
# ----------------
#
# rey-205Ev41.png
# Extracted 94 keypoints.
# ----------------
#
# rey-206Ev5.png
# Extracted 96 keypoints.
# ----------------
#
# rey-202Ev1.png
# Extracted 69 keypoints.
# ----------------
#
# rey-208Ev2.png
# Extracted 130 keypoints.
# ----------------
#
# rey-202Ev3.png
# Extracted 42 keypoints.
# ----------------
#
# rey-204Ev1.png
# Extracted 332 keypoints.
# ----------------
#
# rey-203Ev2.png
# Extracted 101 keypoints.
# ----------------
#
# rey-205Ev3.png
# Extracted 56 keypoints.
# ----------------
#
# rey-202Ev2.png
# Extracted 151 keypoints.
# ----------------
#
# rey-202Ev5.png
# Extracted 72 keypoints.
# ----------------
#
# rey-205Ev1.png
# Extracted 138 keypoints.
# ----------------
#
# rey-212Ev2.png
# Extracted 40 keypoints.
# ----------------
#
# rey-206Ev2.png
# Extracted 95 keypoints.
# ----------------
#
# rey-209Ev2.png
# Extracted 116 keypoints.
# ----------------
#
# rey-213Ev1.png
# Extracted 97 keypoints.
# ----------------
#
# rey-209Ev3.png
# Extracted 158 keypoints.
# ----------------
#
# rey-205Ev4.png
# Extracted 85 keypoints.
# ----------------
