# %%
import numpy as np
import os
import cv2

# %%
def printImage(image):
  from matplotlib import pyplot as plt
  #Show the image with matplotlib
  plt.imshow(image)
  plt.show()

# %%
directory_folder = '/content/dataset2_reyCopia'
directory_tocopy_folder = '/content/dataset2_keypoints'
dir_images = os.listdir(directory_folder)

# %%
orb = cv2.ORB_create()

# %%
def detectKeypoints(image_name):  
  dir_image = f'{directory_folder}/{image_name}' 
  dir_tosave_image = f'{directory_tocopy_folder}/{image_name}'  
  image=cv2.imread(dir_image)
  # Detect keypoints
  keypoints, descriptor = orb.detectAndCompute(image, None)
  
  
  print (image_name)
  print ('Extracted '+str(len(keypoints))+' keypoints.')

  img=cv2.drawKeypoints(image,keypoints,image)
  cv2.imwrite(dir_tosave_image,image)
  printImage(image)
  print ('----------------')
  print ('')

# %%
for image_name in dir_images:
  detectKeypoints(image_name)
# Out:
# rey-210Ev2.png
# Extracted 428 keypoints.
# ----------------
#
# rey-202Ev4.png
# Extracted 480 keypoints.
# ----------------
#
# rey-213Ev1.png
# Extracted 491 keypoints.
# ----------------
#
# rey-206Ev2.png
# Extracted 421 keypoints.
# ----------------
#
# rey-204Ev1.png
# Extracted 469 keypoints.
# ----------------
#
# rey-208Ev2.png
# Extracted 441 keypoints.
# ----------------
#
# rey-205Ev4.png
# Extracted 453 keypoints.
# ----------------
#
# rey-212Ev2.png
# Extracted 361 keypoints.
# ----------------
#
# rey-206Ev3.png
# Extracted 460 keypoints.
# ----------------
#
# rey-203Ev2.png
# Extracted 486 keypoints.
# ----------------
#
# rey-202Ev2.png
# Extracted 480 keypoints.
# ----------------
#
# rey-205Ev1.png
# Extracted 466 keypoints.
# ----------------
#
# rey-202Ev5.png
# Extracted 465 keypoints.
# ----------------
#
# rey-205Ev3.png
# Extracted 461 keypoints.
# ----------------
#
# rey-206Ev5.png
# Extracted 500 keypoints.
# ----------------
#
# rey-202Ev1.png
# Extracted 478 keypoints.
# ----------------
#
# rey-205Ev41.png
# Extracted 477 keypoints.
# ----------------
#
# rey-202Ev3.png
# Extracted 456 keypoints.
# ----------------
#
# rey_modelo.png
# Extracted 500 keypoints.
# ----------------
#
# rey-209Ev3.png
# Extracted 500 keypoints.
# ----------------
#
# rey-209Ev2.png
# Extracted 457 keypoints.
# ----------------
