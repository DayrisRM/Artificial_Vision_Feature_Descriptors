# %%
import numpy as np
import os
import cv2

# %%
directory_folder = '/content/dataset1_reyDistorsiones'
directory_tocopy_folder = '/content/dataset1_keypoints'
dir_images = os.listdir(directory_folder)

# %%
def printImage(image):
  from matplotlib import pyplot as plt
  #Show the image with matplotlib
  plt.imshow(image)
  plt.show()

# %%
# Create detector
fast = cv2.FastFeatureDetector_create()

# %%
def detectKeypoints(image_name):  
  dir_image = f'{directory_folder}/{image_name}' 
  dir_tosave_image = f'{directory_tocopy_folder}/{image_name}'  
  image=cv2.imread(dir_image)
  # Detect keypoints with non max suppression
  keypoints_with_nonmax = fast.detect(image, None)
  
  print (image_name)
  print ('Extracted '+str(len(keypoints_with_nonmax))+' keypoints.')

  img=cv2.drawKeypoints(image,keypoints_with_nonmax,image)
  cv2.imwrite(dir_tosave_image,image)
  printImage(image)
  print ('----------------')
  print ('')

# %%
for image_name in dir_images:
  detectKeypoints(image_name)
# Out:
# t2.png
# Extracted 1235 keypoints.
# ----------------
#
# Modelo.png
# Extracted 579 keypoints.
# ----------------
#
# t3.png
# Extracted 491 keypoints.
# ----------------
#
# t5.png
# Extracted 607 keypoints.
# ----------------
#
# t7.png
# Extracted 487 keypoints.
# ----------------
#
# t6.png
# Extracted 510 keypoints.
# ----------------
#
# t4.png
# Extracted 526 keypoints.
# ----------------
#
# t1.png
# Extracted 932 keypoints.
# ----------------
